# %%
creds = {
  "account"   : "coxasph-epb76465",
  "user"      : "Erick",
  "password"  : "Accenture2024!@",
  "role"      : "ACCOUNTADMIN"
}

# %%
from snowflake.snowpark import Session

# %%
session = Session.builder.configs(creds).create()
# Out:
# c:\ambientes_conda\venv_dags_sf\lib\site-packages\snowflake\connector\config_manager.py:351: UserWarning: Bad owner or permissions on C:\Users\erick.a.perez\.snowflake\connections.toml
#   warn(f"Bad owner or permissions on {str(filep)}{chmod_message}")

# %%
import sys
from snowflake.snowpark.exceptions import SnowparkSQLException

try:
        session.sql(f"""REMOVE @test""").collect()

except SnowparkSQLException as e:
    # Convertir la excepción en un mensaje de texto
    error_message = str(e)
    # Obtener el código de error específico
    error_code = e.error_code
    print(f"Debug: Caught SnowparkSQLException with code {error_code} and message: {error_message}")
    
    # Comprobar si el error es porque el directorio no existe
    if error_code == "1304" in error_message:  
        print(f"Error: The specified directory does not exist: {error_message}")
        sys.exit(1)
    else:
        print(f"An unexpected Snowpark error occurred: {error_message}")
        raise
except Exception as e:
    print(f"An unexpected error occurred: {str(e)}")
    raise
# Out:
# Debug: Caught SnowparkSQLException with code 1304 and message: (1304): 01b5fff6-0106-bf69-0007-8bcb000241aa: 090105 (22000): Cannot perform STAGE RM. This session does not have a current database. Call 'USE DATABASE', or use a qualified name.
# Error: The specified directory does not exist: (1304): 01b5fff6-0106-bf69-0007-8bcb000241aa: 090105 (22000): Cannot perform STAGE RM. This session does not have a current database. Call 'USE DATABASE', or use a qualified name.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[6], line 5
#       4 try:
# ----> 5         session.sql(f"""REMOVE @test""").collect()
#       7 except SnowparkSQLException as e:
#       8     # Convertir la excepción en un mensaje de texto
#
# File c:\ambientes_conda\venv_dags_sf\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:145, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
# ...
